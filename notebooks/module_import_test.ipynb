# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.linspace(0, 10), np.linspace(0, 10))
plt.plot(df)
df.describe().mi()
# Out:
# 0    0.0
# dtype: float64
